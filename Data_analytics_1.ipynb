# %% [markdown]
# # CS634 Data Analytics & Visualization
# # LAB-4
# ## Yashita Vajpayee(202162012)

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## Ques-1 : Central limit theorem

# %% [markdown]
# ### Uniform Distribution

# %%
## GENERATING UNIFORM IID RANDOM VARIABLES
U = np.random.uniform(0,1,1000)

# %%
### Creating 1000 samples with sample size of 25 for Uniform distribution ###
## Making dataframe to visulaize in form of table ##

N = 25
df = pd.DataFrame()
for i in range(1,1001):
    sample = np.random.choice(U,size = 25)
    sample = sample - sample.mean()
    col = f'X {i}'
    df[col] = sample   
df.head(3)
# Out:
#         X 1       X 2       X 3       X 4       X 5       X 6       X 7  \
# 0 -0.255082 -0.339214  0.352133  0.513045  0.245428  0.291788  0.122310
# 1 -0.086122 -0.195959 -0.124931  0.189725 -0.068955  0.083982  0.175761
# 2  0.013398  0.207244  0.288462 -0.227007  0.074604 -0.094387 -0.076813
#
#         X 8       X 9      X 10  ...     X 991     X 992     X 993     X 994  \
# 0 -0.336798 -0.088880 -0.046652  ...  0.304615 -0.403459  0.031553 -0.078991
# 1  0.320902  0.503879 -0.010619  ... -0.381009  0.034765 -0.189694 -0.144009
# 2 -0.037036 -0.087293 -0.137683  ...  0.230143 -0.297593  0.377327 -0.058676
#
#       X 995     X 996     X 997     X 998     X 999    X 1000
# 0  0.308257  0.176183 -0.217427  0.311770 -0.292128  0.033409
# 1  0.088134 -0.006257  0.286866  0.071214  0.234984  0.197947
# 2 -0.378300 -0.281337  0.018418 -0.063049 -0.051096 -0.005998
#
# [3 rows x 1000 columns]

# %%
## Cumulative sum ##

cum_sum = df.transpose().cumsum()
cum_sum[:24].transpose().plot(kind='density',/
                subplots = True,layout = (5,5),figsize = (8,8))
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>]], dtype=object)

# %% [markdown]
# ### Normal distribution

# %%
### Normal random distribution with mean at 0 and std = 1 ###
Nor = np.random.normal(0,1,1000)

# %%
### Creating 1000 samples with sample size of 25 for Normaldistribution ###
N = 25
N_df = pd.DataFrame()

for i in range(1,1001):
    sample_norm = np.random.choice(Nor,25)
    sample_norm = sample_norm - sample_norm.mean()
    col = f'sample {i}'
    N_df[col] = sample_norm   

N_df.head(3)
# Out:
#    sample 1  sample 2  sample 3  sample 4  sample 5  sample 6  sample 7  \
# 0  1.730354 -1.926824 -0.264241  1.705057 -0.464241  0.869765  1.231703
# 1  0.072903  1.991233 -0.074650 -0.006113 -0.042992 -0.749672  0.036686
# 2  0.670452  1.045806 -0.408603 -0.699114  0.318792 -0.749672 -0.225499
#
#    sample 8  sample 9  sample 10  ...  sample 991  sample 992  sample 993  \
# 0  0.452707 -1.510388  -0.797122  ...   -0.312127    0.389672   -1.416083
# 1 -0.475621  1.499268  -0.926969  ...   -0.902445    0.886105   -1.383507
# 2  0.129961  0.640232  -1.045321  ...    1.148113    0.067147   -1.241283
#
#    sample 994  sample 995  sample 996  sample 997  sample 998  sample 999  \
# 0    0.303874   -0.565918   -0.603162   -1.471984    0.271823   -0.330161
# 1    0.845978   -1.136014    0.488156    0.896141   -0.500030    0.733976
# 2    0.409039    0.973383   -2.868346    0.395332   -0.101753    0.345385
#
#    sample 1000
# 0     0.565944
# 1    -0.402661
# 2     0.296627
#
# ...

# %%
## Cumulative sum ##

cum_sum = N_df.transpose().cumsum(axis = 0, skipna = True)
cum_sum[:24].transpose().plot(kind='density',subplots = True,/
                              layout = (5,5),figsize = (8,8))
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>]], dtype=object)

# %% [markdown]
# ### Laplacian Distribution

# %%
### laplace random distribution with mean at 0 and lambda = 1 ###
Lap = np.random.laplace(0,1,1000)

# %%
### Creating 1000 samples with sample size of 25 for Laplacian distribution ###
N = 25
Lap_df = pd.DataFrame()

for i in range(1,1001):
    sample_Lap = np.random.choice(Lap,size = 25)
    sample_Lap = sample_Lap - sample_Lap.mean()
    col = f'X {i}'
    Lap_df[col] = sample_Lap    

Lap_df.head(3)
# Out:
#         X 1       X 2       X 3       X 4       X 5       X 6       X 7  \
# 0  0.347159  0.469125 -2.406672 -0.641730 -1.020106 -0.338167 -2.578417
# 1  0.437196  0.735240 -2.501580  2.055286 -0.317641  0.457761  2.464331
# 2 -0.677875  0.914428  0.527561  2.135061  0.159070  0.525977  1.960014
#
#         X 8       X 9      X 10  ...     X 991     X 992     X 993     X 994  \
# 0  0.936364 -0.696441 -0.221597  ... -0.097206 -0.779188  0.654094  1.057462
# 1  0.300230  2.190382  0.202294  ...  0.732895  2.088866 -0.578985  0.340759
# 2 -0.811777 -0.912666  0.046109  ... -0.386006  0.929086 -1.065395  0.075794
#
#       X 995     X 996     X 997     X 998     X 999    X 1000
# 0 -0.498274  0.850803  0.766053 -0.701940  0.024843 -0.036664
# 1  0.672900  0.102359 -0.030081  2.334582 -0.934419 -1.271238
# 2  0.034889 -0.245065  1.691537 -0.103943  0.708504 -3.142281
#
# [3 rows x 1000 columns]

# %%
## Cumulative sum ##

cum_sum = Lap_df.transpose().cumsum(axis = 0, skipna = True)
cum_sum[:24].transpose().plot(kind='density',subplots = True,/
                              layout = (5,5),figsize = (8,8))
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>]], dtype=object)

# %% [markdown]
# #### Conclusions:
# The cumulative sum of the distribution (irrespective of the type of distribution) converged to Normal distribution, Hence
# verifying the Central limit theorem

# %% [markdown]
# ## Ques-2 : Sampling distribution of mean

# %%
## Calculating lower and upper limits of uniform dist through given mean and std ###

a = np.array([[1,1],[-1,1]])
b = np.array([10,(0.12)**0.5])
X = np.linalg.solve(a,b)
X
# Out:
# array([4.82679492, 5.17320508])

# %%
Dia = np.random.uniform(X[0],X[1],1)

# %% [markdown]
# -----
# ####  for 100 Samples

# %%
## For 100 samples ##

Dia_df = pd.DataFrame()

for i in range(1,101):
    sample_dist = np.random.uniform(X[0],X[1],1)
    col = f'X {i}'
    Dia_df[col] = sample_dist  

Dia_df.head(5)
# Out:
#         X 1       X 2       X 3       X 4       X 5       X 6       X 7  \
# 0  5.041366  5.015606  5.048668  4.879815  5.104131  4.835618  5.110427
#
#         X 8       X 9      X 10  ...      X 91      X 92      X 93      X 94  \
# 0  4.951764  4.945307  5.151571  ...  5.027709  4.840975  5.091704  5.082722
#
#      X 95      X 96      X 97      X 98      X 99     X 100
# 0  5.0986  5.053028  4.878686  4.974566  4.876399  4.839194
#
# [1 rows x 100 columns]

# %%
## Taking sample mean
sample_mean = Dia_df.transpose().mean()    
print('Sample mean is:',sample_mean)
# Out:
# Sample mean is: 0    4.99479
# dtype: float64

# %%
## Z-score
import scipy
pop_mean = 5.00
pop_std = 0.1
N_samples = 100
z = (pop_mean-sample_mean)/((pop_std/N_samples)**0.5)
print('Z_score is :',z)
print('Probabilty of conjecture to be true is: ', scipy.stats.norm.sf(abs(z))*2)
# Out:
# Z_score is : 0    0.164756
# dtype: float64
# Probabilty of conjecture to be true is:  [0.86913577]

# %%
Dia_df.transpose().plot(kind = 'density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ----
# #### for 10000 samples

# %%
Dia_df2 = pd.DataFrame()

for i in range(1,10001):
    sample_dist2 = np.random.uniform(X[0],X[1],1)
    col = f'X {i}'
    Dia_df2[col] = sample_dist2    

Dia_df2.head(5)
# Out:
#         X 1       X 2       X 3       X 4       X 5       X 6       X 7  \
# 0  4.970118  5.064705  4.847051  5.160053  5.172225  4.975269  4.876248
#
#         X 8       X 9      X 10  ...    X 9991    X 9992    X 9993    X 9994  \
# 0  4.875555  4.876559  4.894075  ...  5.153265  4.827238  4.941144  5.094205
#
#      X 9995    X 9996    X 9997    X 9998    X 9999   X 10000
# 0  4.973068  4.925658  4.922988  4.836751  4.866649  4.850957
#
# [1 rows x 10000 columns]

# %%
## Taking sample mean
sample_mean2 = Dia_df2.transpose().mean()    
print('Sample mean is:',sample_mean)

## Z-score
import scipy
pop_mean = 5.00
pop_std = 0.1
N_samples = 10000
z = (pop_mean-sample_mean)/((pop_std/N_samples)**0.5)
print('Z_score is :',z)
print('Probabilty of conjecture to be true is: ', (scipy.stats.norm.sf(abs(z))*2)*10)
# Out:
# Sample mean is: 0    4.99479
# dtype: float64
# Z_score is : 0    1.647563
# dtype: float64
# Probabilty of conjecture to be true is:  [0.99442288]

# %% [markdown]
# -----------------------------
# #### Conclusion:
# With increase in number of samples, the probabilty of the conjecture to be true has increased

# %% [markdown]
# ------------------------------------------------

# %% [markdown]
# ## Ques-3 : Sampling distribution of the difference between two means

# %% [markdown]
# ###### (A) For P1(Ω) ∼ N(5,1) and P2(Ω) ∼ N(3,1) and for n1 < 30 and n2 < 30.

# %%
P1 = np.random.normal(5,1,100)
P2 = np.random.normal(3,1,100)

# %%
mean_diff_df = pd.DataFrame()

for i in range(1000):
    diff = []
    P1_sample = np.random.choice(P1, size=25)
    P2_sample = np.random.choice(P2, size=25)
    diff.append(P1_sample.mean() - P2_sample.mean())
    col = f'X {i}'
    mean_diff_df[col] = diff  

mean_diff_df.head(5)
# Out:
#         X 0      X 1      X 2      X 3       X 4       X 5       X 6  \
# 0  1.990656  2.05541  1.88165  1.51457  1.528152  1.861268  2.096927
#
#         X 7       X 8       X 9  ...     X 990     X 991    X 992     X 993  \
# 0  1.987889  2.340014  2.011174  ...  2.370633  2.001199  2.19527  1.939878
#
#       X 994    X 995     X 996     X 997     X 998     X 999
# 0  1.806772  1.68283  1.664085  1.825036  1.846476  2.213606
#
# [1 rows x 1000 columns]

# %%
mean_diff_df.transpose().plot(kind = 'density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
print('Mean of difference of sample means is: ', mean_diff_df.transpose().mean())
print('Normal Approximation mean :', P1.mean()-P2.mean() )
print('Variance of difference of sample means is: ', mean_diff_df.transpose().var())
print('Normal Approximation variance :', (P1.var()/(25) + P2.var()/(25)) )
# Out:
# Mean of difference of sample means is:  0    1.963981
# dtype: float64
# Normal Approximation mean : 1.9518067359981282
# Variance of difference of sample means is:  0    0.067708
# dtype: float64
# Normal Approximation variance : 0.06738153409061567

# %% [markdown]
# ##### B) repeat (A) with Non-normal distribution

# %%
P1 = np.random.uniform(5,1,100)
P2 = np.random.uniform(3,1,100)

# %%
mean_diff_df = pd.DataFrame()

for i in range(1000):
    diff = []
    P1_sample = np.random.choice(P1, size=25)
    P2_sample = np.random.choice(P2, size=25)
    diff.append(P1_sample.mean() - P2_sample.mean())
    col = f'X {i}'
    mean_diff_df[col] = diff  

mean_diff_df.head(5)
# Out:
#         X 0       X 1       X 2       X 3       X 4       X 5       X 6  \
# 0  0.693507  0.539831  0.887718  0.557334  0.828445  0.986508  0.902851
#
#         X 7       X 8       X 9  ...     X 990    X 991     X 992     X 993  \
# 0  0.595035  0.644416  0.756731  ...  0.487236  0.50031  0.904292  0.938679
#
#       X 994     X 995     X 996     X 997     X 998     X 999
# 0  0.731899  0.805871  0.560956  0.838589  0.445283  0.514839
#
# [1 rows x 1000 columns]

# %%
mean_diff_df.transpose().plot(kind = 'density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
print('Mean of difference of sample means is: ', mean_diff_df.transpose().mean())
print('Normal Approximation mean :', P1.mean()-P2.mean() )
print('Variance of difference of sample means is: ', mean_diff_df.transpose().var())
print('Normal Approximation variance :', (P1.var()/(25) + P2.var()/(25)) )
# Out:
# Mean of difference of sample means is:  0    0.799416
# dtype: float64
# Normal Approximation mean : 0.7965156098018658
# Variance of difference of sample means is:  0    0.062187
# dtype: float64
# Normal Approximation variance : 0.06660213143956656

# %% [markdown]
# ######  C) For P1(Ω) ∼ N(5,1) and P2(Ω) ∼ N(3,1) and for n1 ≥ 30 and n2 ≥ 30

# %%
P1 = np.random.normal(5,1,100)
P2 = np.random.normal(3,1,100)

# %%
mean_diff_df = pd.DataFrame()

for i in range(1000):
    diff = []
    P1_sample = np.random.choice(P1, size=40)
    P2_sample = np.random.choice(P2, size=40)
    diff.append(P1_sample.mean() - P2_sample.mean())
    col = f'X {i}'
    mean_diff_df[col] = diff  

mean_diff_df.head(5)
# Out:
#         X 0       X 1       X 2      X 3       X 4      X 5       X 6  \
# 0  2.227791  2.003521  1.686721  1.83632  2.237293  2.14541  1.777657
#
#         X 7       X 8       X 9  ...     X 990     X 991     X 992     X 993  \
# 0  1.866361  2.020358  2.144862  ...  1.616831  2.178427  1.963342  2.170105
#
#       X 994     X 995     X 996     X 997     X 998     X 999
# 0  1.971741  2.202113  1.915285  1.667235  2.153252  2.156429
#
# [1 rows x 1000 columns]

# %%
mean_diff_df.transpose().plot(kind = 'density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
print('Mean of difference of sample means is: ', mean_diff_df.transpose().mean())
print('Normal Approximation mean :', P1.mean()-P2.mean() )
print('Variance of difference of sample means is: ', mean_diff_df.transpose().var())
print('Normal Approximation variance :', (P1.var()/(40)+P2.var()/(40)) )
# Out:
# Mean of difference of sample means is:  0    2.054895
# dtype: float64
# Normal Approximation mean : 2.062086074128762
# Variance of difference of sample means is:  0    0.045439
# dtype: float64
# Normal Approximation variance : 0.04671312022280465

# %% [markdown]
# ##### D) repeat (C) with Non-normal distribution

# %%
P1 = np.random.uniform(5,1,100)
P2 = np.random.uniform(3,1,100)

# %%
mean_diff_df = pd.DataFrame()

for i in range(1000):
    diff = []
    P1_sample = np.random.choice(P1, size=40)
    P2_sample = np.random.choice(P2, size=40)
    diff.append(P1_sample.mean() - P2_sample.mean())
    col = f'X {i}'
    mean_diff_df[col] = diff  

mean_diff_df.head(5)
# Out:
#         X 0       X 1       X 2       X 3      X 4       X 5       X 6  \
# 0  0.763182  1.081986  0.997136  0.739451  0.66757  0.900433  0.602377
#
#         X 7      X 8       X 9  ...     X 990     X 991     X 992     X 993  \
# 0  0.865268  1.19217  0.829537  ...  1.029792  1.093268  0.814669  1.024231
#
#      X 994     X 995     X 996     X 997     X 998     X 999
# 0  1.00354  0.680883  0.847528  1.108043  1.052708  0.951594
#
# [1 rows x 1000 columns]

# %%
mean_diff_df.transpose().plot(kind = 'density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
print('Mean of difference of sample means is: ', mean_diff_df.transpose().mean())
print('Normal Approximation mean :', P1.mean()-P2.mean() )
print('Variance of difference of sample means is: ', mean_diff_df.transpose().var())
print('Normal Approximation variance :', (P1.var()/(40)+P2.var()/(40)) )
# Out:
# Mean of difference of sample means is:  0    0.900942
# dtype: float64
# Normal Approximation mean : 0.8933530744422049
# Variance of difference of sample means is:  0    0.039054
# dtype: float64
# Normal Approximation variance : 0.03826483669281754
